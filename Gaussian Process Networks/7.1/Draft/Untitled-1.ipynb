# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import DotProduct

X = np.linspace(0, 10, 100)[:, None]
y = X * np.sin(X)

kernel = DotProduct()
gpr = GaussianProcessRegressor(kernel=kernel)
gpr.fit(X, y)

X_test = np.linspace(0, 10, 200)[:, None]
mean, std = gpr.predict(X_test, return_std=True)

plt.plot(X_test, mean, label='Mean')
plt.plot(X_test, mean + 1e6 * std, label='+1 std', color='blue', linestyle='dashed')
plt.plot(X_test, mean - 1e6 * std, label='-1 std', color='blue', linestyle='dashed')
# plt.plot(X, y, 'o', label='Data')
plt.legend()
plt.show()

# %%
print(std)
# Out:
# [1.98518480e-06 1.97022430e-06 1.95540484e-06 1.94087267e-06
#  1.92594266e-06 1.91107029e-06 1.89637402e-06 1.88191696e-06
#  1.86734798e-06 1.85284420e-06 1.83834678e-06 1.82391674e-06
#  1.80949433e-06 1.79520344e-06 1.78086021e-06 1.76665191e-06
#  1.75264516e-06 1.73827011e-06 1.72435475e-06 1.71058581e-06
#  1.69663970e-06 1.68270996e-06 1.66826469e-06 1.65449868e-06
#  1.64102315e-06 1.62729959e-06 1.61400970e-06 1.60005447e-06
#  1.58653637e-06 1.57403104e-06 1.55929100e-06 1.54713957e-06
#  1.53416844e-06 1.52064872e-06 1.50730236e-06 1.49517393e-06
#  1.48264682e-06 1.46971083e-06 1.45726957e-06 1.44472118e-06
#  1.43392226e-06 1.42085522e-06 1.40798233e-06 1.39467227e-06
#  1.38380370e-06 1.37220197e-06 1.36115399e-06 1.34804045e-06
#  1.33646055e-06 1.32544970e-06 1.31535986e-06 1.30246719e-06
#  1.29288506e-06 1.28115328e-06 1.27141053e-06 1.26088833e-06
#  1.25098776e-06 1.23957600e-06 1.23094776e-06 1.22007665e-06
# ...
